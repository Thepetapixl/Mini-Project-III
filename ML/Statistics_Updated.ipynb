# %%
# importing libraries to use dataset

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Reading the csv dataset to perform operations on it

df = pd.read_csv(r"C:\Users\Rupeshwar\Desktop\Car_Parking.csv")

# %%
# Finding out how many rows and columns does dataset have 
print(df.shape)
# Out:
# (127, 9)

# %%
# Finding out the entries which have given a rating of 4.5 and above

df.loc[df['Rating'] >= 4.5]
# Out:
#      S.No                       Name        Vechile_No Time-In Time-Out  \
# 0     1.0                  Denver. R   MH-123-XX--0001    9:20    10:00
# 3     4.0            Charles. Xavier   MH-123-XX--0004   17:00    20:40
# 6     7.0           Hanumant. Tiwari   MH-123-XX--0007   10:00    16:00
# 11   12.0                     Shweta   MH-123-XX--0012   17:30    18:00
# 12   13.0               Swaroop.Khan   GJ-456-TYU-5678   22:00    21:00
# 15   16.0               Khushagra. S   MH-123-XX--0016   10:00    11:00
# 16   17.0             Khushi. Tagore   MH-123-XX--0017   12:10    16:45
# 20    3.0                     Sluger   MH-123-XX--0001    9:20    10:00
# 23    6.0              Storm. Shadow   MH-123-XX--0004   19:20    13:00
# 26    9.0                Quete.Blank   MH-123-XX--0007    5:20    16:00
# 29   12.0              Antonio. Clik   MH-123-XX--0010   15:20    19:00
# 31   14.0                     Shrija   MH-123-XX--0012   22:00     5:00
# 32   15.0                   Jagadale   GJ-456-TYU-5678    1:20    22:00
# 35   18.0               Rohit. Gajar   MH-123-XX--0016   11:20     1:00
# 36   19.0                 Rohit. Jha   MH-123-XX--0017   14:40    18:00
# 40    2.0                Aaron, Hank   MH-123-XX--0001    9:20    10:00
# 43    5.0               Abel, Reuben  CG-007-TYGF-0046   17:00    20:40
# 46    8.0          Abrams, Creighton   MH-123-XX--0005   10:00    16:00
# 51   13.0  Eddington, Arthur Stanley  CG-007-TYGF-0050   17:30    18:00
# 52   14.0        Edison, Thomas Alva   MH-123-XX--0008   22:00    21:00
# 55   17.0              Edwards, John  CG-007-TYGF-0052   10:00    11:00
# 56   18.0               Eggers, Dave   MH-123-XX--0010   12:10    16:45
# 60    2.0      Eisenstein, Ferdinand   MH-123-XX--0012    9:20    10:00
# 63    5.0         ElBaradei, Mohamed  CG-007-TYGF-0056   19:20    13:00
# 67    9.0      Fulbright, J. William  CG-007-TYGF-0058    5:20    16:00
# 71   13.0                     Olivia   MH-123-XX--0017   15:20    19:00
# 73   15.0                        Ava  CG-007-TYGF-0060   22:00     5:00
# 74   16.0                   Avataram   MH-123-XX--0018    1:20    22:00
# 78   20.0                       Lucy   MH-123-XX--0019   14:40    18:00
# 79    1.0                       Paul  CG-007-TYGF-0062   18:00    11:00
# 82    4.0                      Harsh  CG-007-TYGF-0063    9:20    10:00
# 85    7.0                Madeline. L  CG-007-TYGF-0064   17:00    20:40
# 88   10.0                      Sarah  CG-007-TYGF-0065   10:00    16:00
# 91   13.0                   Stefan.S  CG-007-TYGF-0066   17:30    22:00
# 93   15.0                   Elijah.M   MH-123-XX--0024   17:30    18:00
# 94   16.0                 Caroline.S  CG-007-TYGF-0067   22:00    21:00
# 95   17.0                      Gajar   MH-123-XX--0025   12:00    17:30
# 97   19.0            Savannh. Shaikh  CG-007-TYGF-0068   10:00    11:00
# 98   20.0                   Aurota.L   MH-123-XX--0026   12:10    16:45
# 99   21.0                     Smitha   MH-123-XX--0024    9:20    10:00
# 103  25.0                  Among. Us   MH-123-XX--0025   18:16    20:45
# 104  26.0                 Counter .S  CG-007-TYGF-0069   16:00    19:34
# 107  29.0                    Yaman.I   MH-123-XX--0024   12:15    13:00
# 110  32.0             Krish. Agarwal   MH-123-XX--0025   17:30    18:00
#
#      Duration  Amount  Rating    Year
# 0        40.0    13.3     4.5  2016.0
# 3       220.0    73.3     4.5  2016.0
# 6       360.0   120.0     5.0  2016.0
# 11       30.0    10.0     5.0  2016.0
# 12       60.0    20.0     4.8  2016.0
# 15       60.0    20.0     4.5  2016.0
# 16      285.0     9.3     5.0  2016.0
# 20       40.0    13.3     4.5  2017.0
# 23      580.0   193.3     4.5  2017.0
# 26     1120.0   373.3     5.0  2017.0
# 29     1660.0   553.3     5.0  2017.0
# 31     2020.0   673.3     5.0  2017.0
# 32     2200.0   733.3     4.8  2017.0
# 35     2740.0   913.3     4.5  2017.0
# 36     2920.0   973.3     5.0  2017.0
# 40       40.0    13.3     4.5  2018.0
# 43      220.0    73.3     4.5  2018.0
# 46      360.0   120.0     5.0  2018.0
# 51       30.0    10.0     5.0  2018.0
# 52       60.0    20.0     4.8  2018.0
# 55       60.0    20.0     4.5  2018.0
# 56      285.0     9.3     5.0  2018.0
# 60       40.0    20.0     4.5  2019.0
# 63      580.0    12.0     4.5  2019.0
# 67     1120.0    90.0     5.0  2019.0
# 71      360.0    20.0     5.0  2019.0
# 73       45.0    56.0     5.0  2019.0
# 74      330.0    12.0     4.5  2019.0
# 78      330.0    90.0     5.0  2019.0
# 79       50.0    89.0     4.5  2020.0
# 82       15.0    89.0     5.0  2020.0
# 85       40.0    20.0     4.5  2020.0
# 88      220.0    12.0     4.5  2020.0
# 91      181.0     7.0     4.5  2020.0
# 93      360.0    89.0     5.0  2020.0
# 94      333.0    10.0     5.0  2020.0
# 95       45.0    12.0     4.5  2020.0
# 97      180.0    76.0     4.9  2020.0
# 98       40.0    34.0     5.0  2020.0
# 99       40.0   100.0     4.5  2016.0
# 103     181.0    21.0     5.0  2016.0
# 104     214.0    12.0     4.5  2018.0
# 107      45.0    56.0     5.0  2018.0
# 110      30.0    64.0     4.5  2018.0

# %%
#Plotting a bar Graph to indicate the performance of the system

df.plot(x="Year", y="Amount", kind="bar")

# %%
# Addition of the Revenue collected in these Years

y_2016 = df.loc[df['Year'] == 2016, 'Amount'].sum()

y_2017 = df.loc[df['Year'] == 2017, 'Amount'].sum()

y_2018 = df.loc[df['Year'] == 2018, 'Amount'].sum()

y_2019 = df.loc[df['Year'] == 2019, 'Amount'].sum()

y_2020 = df.loc[df['Year'] == 2020, 'Amount'].sum()

# %%
# Performance in terms of Revenue generated by the Parking System over the years
years = [y_2016,y_2017,y_2018,y_2019,y_2020]

my_labels = '2016','2017','2018','2019','2020'
my_colors = ['Red','Blue','Black', 'Yellow','Violet']
plt.pie(years,labels=my_labels,autopct='%1.1f%%')
plt.title('Revenue')
plt.axis('equal')
plt.show()

# %%
# Displaying enteries in each year

addition = df['Year'].value_counts()
print(addition)
# Out:
# 2017.0    25
# 2018.0    24
# 2016.0    22
# 2020.0    21
# 2019.0    20
# Name: Year, dtype: int64

# %%
# Adding all records(car enteries) in each years=

cars_16 = df.loc[df.Year == 2016, 'Year'].count()
cars_17 = df.loc[df.Year == 2017, 'Year'].count()
cars_18 = df.loc[df.Year == 2018, 'Year'].count()
cars_19 = df.loc[df.Year == 2019, 'Year'].count()
cars_20 = df.loc[df.Year == 2020, 'Year'].count()

# %%
# Performance in terms of Cars parked in the Parking System over the years
cars_year = [cars_16, cars_17, cars_18, cars_19, cars_20]

my_labels = '2016','2017','2018','2019','2020'
my_colors = ['Red','Blue','Black', 'Yellow','Violet']
plt.pie(cars_year,labels=my_labels,autopct='%1.1f%%')
plt.title('Cars Parked')
plt.axis('equal')
plt.show()
